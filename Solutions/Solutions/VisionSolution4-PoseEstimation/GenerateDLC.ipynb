# %% [markdown]
# ## Steps for generating object_detect.dlc
#
# For this demo, a YoloNAS model is used. You can read more about this model in VisionSolution1-YoloNasSSD Readme.
#
# #### Note->Use python3.8 or above for generating onnx and python3.6 for generating dlc

# %%
## Note- Use python3.8 or above for generating onnx

# !pip install super-gradients==3.1.2


## Downloading Model from git repo
import torch
# Load model with pretrained weights
from super_gradients.training import models
from super_gradients.common.object_names import Models

model = models.get(Models.YOLO_NAS_S, pretrained_weights="coco")

# Prepare model for conversion
# Input size is in format of [Batch x Channels x Width x Height] where 640 is the standard COCO dataset dimensions
model.eval()
model.prep_model_for_conversion(input_size=[1, 3, 320, 320])

# Create dummy_input
dummy_input = torch.randn([1, 3, 320, 320], device="cpu")

# Convert model to onnx
torch.onnx.export(model, dummy_input, "yolo_nas_s.onnx", opset_version=11)

# %% [markdown]
# #### Enable python3.6 environment, to use SNPE SDK and then convert onnx to dlc

# %%
# %%bash
# snpe-onnx-to-dlc -i yolo_nas_s.onnx -o app/src/main/assets/yolo_nas_s.dlc

# %% [markdown]
# ## Quantizing MobileNetSSD

# %%
##STEPS to preprocess images

def preprocess(original_image):
    resized_image = cv2.resize(original_image, (320, 320))
    resized_image = resized_image/255
    return resized_image

import cv2
import numpy as np
import os

##Please download Coco2014 dataset and give the path here
dataset_path = "/workspace/val2014/"

# !mkdir -p rawYoloNAS

filenames=[]
for path in os.listdir(dataset_path)[:5]:
    # check if current path is a file
    if os.path.isfile(os.path.join(dataset_path, path)):
        filenames.append(os.path.join(dataset_path, path))

for filename in filenames:
    original_image = cv2.imread(filename)
    img = preprocess(original_image)
    img = img.astype(np.float32)
    img.tofile("rawYoloNAS/"+filename.split("/")[-1].split(".")[0]+".raw")

# %%
# %%bash
# find rawYoloNAS -name *.raw > YoloInputlist.txt

# %%
# %%bash
# cat YoloInputlist.txt

# %%
# %%bash
# snpe-dlc-quantize --input_dlc app/src/main/assets/yolo_nas_s.dlc --input_list YoloInputlist.txt --use_enhanced_quantizer --use_adjusted_weights_quantizer --axis_quant --output_dlc app/src/main/assets/Quant_yoloNas_s_320.dlc

# %% [markdown]
# ## How to change the object-detect model ?
#
# Object detection models are highly dependant on model architecture, and the pre-processing requirements vary a lot from model to model.
# If user intends to use a different model e.g. YoloV5, following steps should be followed :
#
# - Ensure Qualcomm® Neural Processing SDK supports the operations in selected model
# - Study the pre processing, and post processing requirements for the selected model
# - Most object detection models operate in RGB space. Input camera YUV buffers need to be converted to RGB basd on model requirements

# %% [markdown]
# # Info about HRNET
#
# HRNET model is State-of-the-art model for human pose estimation. It has good accuracy for results with single person, but has lower accuracy for multiple persons. To enhance that, HRNET uses object-detect model to identify a single person in a frame and then give the data to HRNET to get pose of that person. In this solution, we use MobileNetSSD for detecting human and then give the preprocesssed data to HRNET to achieve better accuracy for pose estimation.
#
# HRNET dlc takes 256x192x3 flattened array as input and returns output of dims 17x64x48. HRNET generates heatmap for 17 human joints and each heatmap is of size 64x48.

# %%
#Get PTH file and generate onnx file from it
# !pwd
# !git clone https://github.com/HRNet/HRNet-Human-Pose-Estimation.git
# %cd HRNet-Human-Pose-Estimation/
# !git checkout 00d7bf72f56382165e504b10ff0dddb82dca6fd2
# %cd ..
# Out:
# /local/mnt/workspace/shubgoya/native_doc/test_generateDLC_native
# Cloning into 'HRNet-Human-Pose-Estimation'...
# remote: Enumerating objects: 140, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 140 (delta 0), reused 1 (delta 0), pack-reused 137
# Receiving objects: 100% (140/140), 1.69 MiB | 8.05 MiB/s, done.
# Resolving deltas: 100% (64/64), done.
# /local/mnt/workspace/shubgoya/native_doc/test_generateDLC_native/HRNet-Human-Pose-Estimation
# Note: checking out '00d7bf72f56382165e504b10ff0dddb82dca6fd2'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by performing another checkout.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -b with the checkout command again. Example:
#
#   git checkout -b <new-branch-name>
#
# HEAD is now at 00d7bf7 Update README.md
# /local/mnt/workspace/shubgoya/native_doc/test_generateDLC_native

# %%
# %%bash
# cd HRNet-Human-Pose-Estimation/lib
# make
# cd ../..
# Out:
# cd nms; python setup_linux.py build_ext --inplace; rm -rf build; cd ../../
# running build_ext
# skipping 'cpu_nms.c' Cython extension (up-to-date)
# skipping 'gpu_nms.cpp' Cython extension (up-to-date)

# %%
import torch
import numpy as np
# %matplotlib inline
from matplotlib import pyplot as plt
import sys

import os
import os.path as osp

# def add_path(path):
#     if path not in sys.path:
#         sys.path.insert(0, path)

lib_path = osp.join(os.getcwd(), 'HRNet-Human-Pose-Estimation/lib')
sys.path.insert(0, lib_path)

import torch
import torch.utils.data
import torchvision.transforms as transforms
from config import cfg
from dataset.coco import COCODataset

# %%
# !mkdir -p model_binaries

# %%
# %cd model_binaries
# !mv HRNet-Human-Pose-Estimation/lib/* . 
# !cp -R -T -f ./HRNet-Human-Pose-Estimation/lib/ . 


import os
import torch
import urllib.request

torch.__version__
# print(torch.__version_)

##Getting .pth file
OPTIMIZED_CHECKPOINT_URL = (
    "https://github.com/quic/aimet-model-zoo/releases/download/hrnet-posenet/"
)

if not os.path.exists(f"./model_binaries/hrnet_posenet_FP32.pth"):
    urllib.request.urlretrieve(
        f"{OPTIMIZED_CHECKPOINT_URL}/hrnet_posenet_FP32.pth",
        f"model_binaries/hrnet_posenet_FP32.pth",
    )


input_shape = (1, 3, 256, 192)
dummy_input = torch.randn(input_shape)
model = torch.load("model_binaries/hrnet_posenet_FP32.pth")
model.to('cpu')

onnx_model_name = "model_binaries/AIMET_HRNET_posnet.onnx"

opset = 11

torch.onnx.export(
    model.cpu(),
    dummy_input,
    onnx_model_name,
    verbose=True,
    do_constant_folding=True,
    export_params=True,
    input_names=['input'],
    output_names=['output'],
    opset_version=opset
)
# Out:
# graph(%input : Float(1, 3, 256, 192, strides=[147456, 49152, 192, 1], requires_grad=0, device=cpu),
#       %final_layer.weight : Float(17, 32, 1, 1, strides=[32, 1, 1, 1], requires_grad=1, device=cpu),
#       %final_layer.bias : Float(17, strides=[1], requires_grad=1, device=cpu),
#       %2903 : Float(64, 3, 3, 3, strides=[27, 9, 3, 1], requires_grad=0, device=cpu),
#       %2904 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %2906 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cpu),
#       %2907 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %2909 : Float(64, 64, 1, 1, strides=[64, 1, 1, 1], requires_grad=0, device=cpu),
#       %2910 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %2912 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cpu),
#       %2913 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %2915 : Float(256, 64, 1, 1, strides=[64, 1, 1, 1], requires_grad=0, device=cpu),
#       %2916 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %2918 : Float(256, 64, 1, 1, strides=[64, 1, 1, 1], requires_grad=0, device=cpu),
#       %2919 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %2921 : Float(64, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=0, device=cpu),
#       %2922 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %2924 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cpu),
#       %2925 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %2927 : Float(256, 64, 1, 1, strides=[64, 1, 1, 1], requires_grad=0, device=cpu),
#       %2928 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %2930 : Float(64, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=0, device=cpu),
#       %2931 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %2933 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cpu),
#       %2934 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %2936 : Float(256, 64, 1, 1, strides=[64, 1, 1, 1], requires_grad=0, device=cpu),
#       %2937 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %2939 : Float(64, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=0, device=cpu),
#       %2940 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %2942 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cpu),
#       %2943 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %2945 : Float(256, 64, 1, 1, strides=[64, 1, 1, 1], requires_grad=0, device=cpu),
#       %2946 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %2948 : Float(32, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=0, device=cpu),
#       %2949 : Float(32, strides=[1], requires_grad=0, device=cpu),
#       %2951 : Float(64, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=0, device=cpu),
#       %2952 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %2954 : Float(32, 32, 3, 3, strides=[288, 9, 3, 1], requires_grad=0, device=cpu),
#       %2955 : Float(32, strides=[1], requires_grad=0, device=cpu),
#       %2957 : Float(32, 32, 3, 3, strides=[288, 9, 3, 1], requires_grad=0, device=cpu),
#       %2958 : Float(32, strides=[1], requires_grad=0, device=cpu),
#       %2960 : Float(32, 32, 3, 3, strides=[288, 9, 3, 1], requires_grad=0, device=cpu),
#       %2961 : Float(32, strides=[1], requires_grad=0, device=cpu),
#       %2963 : Float(32, 32, 3, 3, strides=[288, 9, 3, 1], requires_grad=0, device=cpu),
#       %2964 : Float(32, strides=[1], requires_grad=0, device=cpu),
#       %2966 : Float(32, 32, 3, 3, strides=[288, 9, 3, 1], requires_grad=0, device=cpu),
#       %2967 : Float(32, strides=[1], requires_grad=0, device=cpu),
#       %2969 : Float(32, 32, 3, 3, strides=[288, 9, 3, 1], requires_grad=0, device=cpu),
#       %2970 : Float(32, strides=[1], requires_grad=0, device=cpu),
#       %2972 : Float(32, 32, 3, 3, strides=[288, 9, 3, 1], requires_grad=0, device=cpu),
#       %2973 : Float(32, strides=[1], requires_grad=0, device=cpu),
#       %2975 : Float(32, 32, 3, 3, strides=[288, 9, 3, 1], requires_grad=0, device=cpu),
#       %2976 : Float(32, strides=[1], requires_grad=0, device=cpu),
#       %2978 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cpu),
#       %2979 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %2981 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cpu),
#       %2982 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %2984 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cpu),
#       %2985 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %2987 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cpu),
#       %2988 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %2990 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cpu),
#       %2991 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %
: Float(1, 128, 16, 12, strides=[24576, 192, 12, 1], requires_grad=1, device=cpu) = onnx::Relu(%3727) # /local/mnt/workspace/AppData/env/py_tf_2x/lib/python3.6/site-packages/torch/nn/functional.py:1297:0
#   %3730 : Float(1, 128, 16, 12, strides=[24576, 192, 12, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%2829, %3731, %3732)
#   %2832 : Float(1, 128, 16, 12, strides=[24576, 192, 12, 1], requires_grad=1, device=cpu) = onnx::Add(%3730, %2826) # /local/mnt/workspace/shubgoya/native_doc/test_generateDLC_native/HRNet-Human-Pose-Estimation/lib/models/pose_hrnet.py:54:0
#   %2833 : Float(1, 128, 16, 12, strides=[24576, 192, 12, 1], requires_grad=1, device=cpu) = onnx::Relu(%2832)
#   %3733 : Float(1, 128, 16, 12, strides=[24576, 192, 12, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%2833, %3734, %3735)
#   %2836 : Float(1, 128, 16, 12, strides=[24576, 192, 12, 1], requires_grad=1, device=cpu) = onnx::Relu(%3733) # /local/mnt/workspace/AppData/env/py_tf_2x/lib/python3.6/site-packages/torch/nn/functional.py:1297:0
#   %3736 : Float(1, 128, 16, 12, strides=[24576, 192, 12, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%2836, %3737, %3738)
#   %2839 : Float(1, 128, 16, 12, strides=[24576, 192, 12, 1], requires_grad=1, device=cpu) = onnx::Add(%3736, %2833) # /local/mnt/workspace/shubgoya/native_doc/test_generateDLC_native/HRNet-Human-Pose-Estimation/lib/models/pose_hrnet.py:54:0
#   %2840 : Float(1, 128, 16, 12, strides=[24576, 192, 12, 1], requires_grad=1, device=cpu) = onnx::Relu(%2839)
#   %3739 : Float(1, 128, 16, 12, strides=[24576, 192, 12, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%2840, %3740, %3741)
#   %2843 : Float(1, 128, 16, 12, strides=[24576, 192, 12, 1], requires_grad=1, device=cpu) = onnx::Relu(%3739) # /local/mnt/workspace/AppData/env/py_tf_2x/lib/python3.6/site-packages/torch/nn/functional.py:1297:0
#   %3742 : Float(1, 128, 16, 12, strides=[24576, 192, 12, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%2843, %3743, %3744)
#   %2846 : Float(1, 128, 16, 12, strides=[24576, 192, 12, 1], requires_grad=1, device=cpu) = onnx::Add(%3742, %2840) # /local/mnt/workspace/shubgoya/native_doc/test_generateDLC_native/HRNet-Human-Pose-Estimation/lib/models/pose_hrnet.py:54:0
#   %2847 : Float(1, 128, 16, 12, strides=[24576, 192, 12, 1], requires_grad=1, device=cpu) = onnx::Relu(%2846) # /local/mnt/workspace/AppData/env/py_tf_2x/lib/python3.6/site-packages/torch/nn/functional.py:1297:0
#   %3745 : Float(1, 256, 8, 6, strides=[12288, 48, 6, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%2763, %3746, %3747)
#   %2850 : Float(1, 256, 8, 6, strides=[12288, 48, 6, 1], requires_grad=1, device=cpu) = onnx::Relu(%3745) # /local/mnt/workspace/AppData/env/py_tf_2x/lib/python3.6/site-packages/torch/nn/functional.py:1297:0
#   %3748 : Float(1, 256, 8, 6, strides=[12288, 48, 6, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%2850, %3749, %3750)
#   %2853 : Float(1, 256, 8, 6, strides=[12288, 48, 6, 1], requires_grad=1, device=cpu) = onnx::Add(%3748, %2763) # /local/mnt/workspace/shubgoya/native_doc/test_generateDLC_native/HRNet-Human-Pose-Estimation/lib/models/pose_hrnet.py:54:0
#   %2854 : Float(1, 256, 8, 6, strides=[12288, 48, 6, 1], requires_grad=1, device=cpu) = onnx::Relu(%2853)
#   %3751 : Float(1, 256, 8, 6, strides=[12288, 48, 6, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%2854, %3752, %3753)
#   %2857 : Float(1, 256, 8, 6, strides=[12288, 48, 6, 1], requires_grad=1, device=cpu) = onnx::Relu(%3751) # /local/mnt/workspace/AppData/env/py_tf_2x/lib/python3.6/site-packages/torch/nn/functional.py:1297:0
#   %3754 : Float(1, 256, 8, 6, strides=[12288, 48, 6, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%2857, %3755, %3756)
#   %2860 : Float(1, 256, 8, 6, strides=[12288, 48, 6, 1], requires_grad=1, device=cpu) = onnx::Add(%3754, %2854) # /local/mnt/workspace/shubgoya/native_doc/test_generateDLC_native/HRNet-Human-Pose-Estimation/lib/models/pose_hrnet.py:54:0
#   %2861 : Float(1, 256, 8, 6, strides=[12288, 48, 6, 1], requires_grad=1, device=cpu) = onnx::Relu(%2860)
#   %3757 : Float(1, 256, 8, 6, strides=[12288, 48, 6, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%2861, %3758, %3759)
#   %2864 : Float(1, 256, 8, 6, strides=[12288, 48, 6, 1], requires_grad=1, device=cpu) = onnx::Relu(%3757) # /local/mnt/workspace/AppData/env/py_tf_2x/lib/python3.6/site-packages/torch/nn/functional.py:1297:0
#   %3760 : Float(1, 256, 8, 6, strides=[12288, 48, 6, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%2864, %3761, %3762)
#   %2867 : Float(1, 256, 8, 6, strides=[12288, 48, 6, 1], requires_grad=1, device=cpu) = onnx::Add(%3760, %2861) # /local/mnt/workspace/shubgoya/native_doc/test_generateDLC_native/HRNet-Human-Pose-Estimation/lib/models/pose_hrnet.py:54:0
#   %2868 : Float(1, 256, 8, 6, strides=[12288, 48, 6, 1], requires_grad=1, device=cpu) = onnx::Relu(%2867)
#   %3763 : Float(1, 256, 8, 6, strides=[12288, 48, 6, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%2868, %3764, %3765)
#   %2871 : Float(1, 256, 8, 6, strides=[12288, 48, 6, 1], requires_grad=1, device=cpu) = onnx::Relu(%3763) # /local/mnt/workspace/AppData/env/py_tf_2x/lib/python3.6/site-packages/torch/nn/functional.py:1297:0
#   %3766 : Float(1, 256, 8, 6, strides=[12288, 48, 6, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%2871, %3767, %3768)
#   %2874 : Float(1, 256, 8, 6, strides=[12288, 48, 6, 1], requires_grad=1, device=cpu) = onnx::Add(%3766, %2868) # /local/mnt/workspace/shubgoya/native_doc/test_generateDLC_native/HRNet-Human-Pose-Estimation/lib/models/pose_hrnet.py:54:0
#   %2875 : Float(1, 256, 8, 6, strides=[12288, 48, 6, 1], requires_grad=1, device=cpu) = onnx::Relu(%2874) # /local/mnt/workspace/AppData/env/py_tf_2x/lib/python3.6/site-packages/torch/nn/functional.py:1297:0
#   %3769 : Float(1, 32, 32, 24, strides=[24576, 768, 24, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%2819, %3770, %3771)
#   %2881 : Float(0, strides=[1], device=cpu) = onnx::Constant[value=[ CPUFloatType{0} ]]()
#   %2882 : Float(1, 32, 64, 48, strides=[98304, 3072, 48, 1], requires_grad=1, device=cpu) = onnx::Resize[coordinate_transformation_mode="asymmetric", cubic_coeff_a=-0.75, mode="nearest", nearest_mode="floor"](%3769, %2881, %3803) # /local/mnt/workspace/AppData/env/py_tf_2x/lib/python3.6/site-packages/torch/nn/functional.py:3712:0
#   %2883 : Float(1, 32, 64, 48, strides=[98304, 3072, 48, 1], requires_grad=1, device=cpu) = onnx::Add(%2791, %2882) # /local/mnt/workspace/shubgoya/native_doc/test_generateDLC_native/HRNet-Human-Pose-Estimation/lib/models/pose_hrnet.py:262:0
#   %3772 : Float(1, 32, 16, 12, strides=[6144, 192, 12, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%2847, %3773, %3774)
#   %2889 : Float(0, strides=[1], device=cpu) = onnx::Constant[value=[ CPUFloatType{0} ]]()
#   %2890 : Float(1, 32, 64, 48, strides=[98304, 3072, 48, 1], requires_grad=1, device=cpu) = onnx::Resize[coordinate_transformation_mode="asymmetric", cubic_coeff_a=-0.75, mode="nearest", nearest_mode="floor"](%3772, %2889, %3804) # /local/mnt/workspace/AppData/env/py_tf_2x/lib/python3.6/site-packages/torch/nn/functional.py:3712:0
#   %2891 : Float(1, 32, 64, 48, strides=[98304, 3072, 48, 1], requires_grad=1, device=cpu) = onnx::Add(%2883, %2890) # /local/mnt/workspace/shubgoya/native_doc/test_generateDLC_native/HRNet-Human-Pose-Estimation/lib/models/pose_hrnet.py:262:0
#   %3775 : Float(1, 32, 8, 6, strides=[1536, 48, 6, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%2875, %3776, %3777)
#   %2897 : Float(0, strides=[1], device=cpu) = onnx::Constant[value=[ CPUFloatType{0} ]]()
#   %2898 : Float(1, 32, 64, 48, strides=[98304, 3072, 48, 1], requires_grad=1, device=cpu) = onnx::Resize[coordinate_transformation_mode="asymmetric", cubic_coeff_a=-0.75, mode="nearest", nearest_mode="floor"](%3775, %2897, %3805) # /local/mnt/workspace/AppData/env/py_tf_2x/lib/python3.6/site-packages/torch/nn/functional.py:3712:0
#   %2899 : Float(1, 32, 64, 48, strides=[98304, 3072, 48, 1], requires_grad=1, device=cpu) = onnx::Add(%2891, %2898) # /local/mnt/workspace/shubgoya/native_doc/test_generateDLC_native/HRNet-Human-Pose-Estimation/lib/models/pose_hrnet.py:262:0
#   %2900 : Float(1, 32, 64, 48, strides=[98304, 3072, 48, 1], requires_grad=1, device=cpu) = onnx::Relu(%2899) # /local/mnt/workspace/AppData/env/py_tf_2x/lib/python3.6/site-packages/torch/nn/functional.py:1297:0
#   %output : Float(1, 17, 64, 48, strides=[52224, 3072, 48, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%2900, %final_layer.weight, %final_layer.bias) # /local/mnt/workspace/AppData/env/py_tf_2x/lib/python3.6/site-packages/torch/nn/modules/conv.py:443:0
#   return (%output)

# %%
# !rm -r -f HRNet-Human-Pose-Estimation

# %% [markdown]
# ## Steps for generating HRNET dlc for int8

# %%
# %%bash
# snpe-onnx-to-dlc -i model_binaries/AIMET_HRNET_posnet.onnx -o app/src/main/assets/hrnet.dlc
# Out:
# 2023-05-12 12:26:44,332 - 214 - INFO - Successfully simplified the onnx model in child process
# 2023-05-12 12:26:44,859 - 214 - INFO - Successfully receive the simplified onnx model in main process
# 2023-05-12 12:26:47,290 - 214 - INFO - INFO_INITIALIZATION_SUCCESS:
# 2023-05-12 12:26:47,662 - 214 - INFO - INFO_CONVERSION_SUCCESS: Conversion completed successfully
# 2023-05-12 12:26:47,792 - 214 - INFO - INFO_WRITE_SUCCESS:

# %% [markdown]
# ## Steps for Quantization

# %%
from PIL import Image
normalize = transforms.Normalize(
    mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]
)

preproc = transforms.Compose(
        [
            transforms.ToTensor(),
            normalize,
        ]
    )

# %%
##Add your dataset path
dataset_path = "/local/mnt/workspace/shubgoya/val2014/"

##Make empty directory
# !mkdir -p rawHRNET

import cv2,os
filenames=[]
for path in os.listdir(dataset_path)[:5]:
    # check if current path is a file
    if os.path.isfile(os.path.join(dataset_path, path)):
        filenames.append(os.path.join(dataset_path, path))
print(filenames)

for filename in filenames:
    orig_img = cv2.imread(filename)
    img = cv2.cvtColor(orig_img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img,(256,192),
                   interpolation = cv2.INTER_LINEAR)
    model_input = preproc(img).unsqueeze(0)

    model_input = model_input.cpu().detach().numpy()
    model_input = model_input.transpose(0,2,3,1)     
    fid = open("rawHRNET/"+filename.split("/")[-1].split(".")[0]+".raw", 'wb')
    model_input.tofile(fid)

# %%
# %%bash
#
# ##Creating raw files - TODO
# find rawHRNET -name *.raw > HRNET_input_list.txt
#
# ## Quantization
# snpe-dlc-quant --input_dlc app/src/main/assets/hrnet.dlc --input_list HRNET_input_list.txt --axis_quant --output_dlc app/src/main/assets/hrnet_axis_int8.dlc
# Out:
# [INFO] InitializeStderr: DebugLog initialized.
# [INFO] Attempting to open dynimcally linked lib: libHtpPrepare.so
# [INFO] dlopen libHtpPrepare.so SUCCESS handle 0x1695650
# [INFO] Found Interface Provider (v2.3)
# [USER_INFO] QnnDsp <I> Qnn log initialized
# [USER_INFO] QnnDsp <I> addClient done (1). status 0x0
# [USER_INFO] QnnDsp <I> addClient started.
# [USER_INFO] QnnDsp <I> OpValidatorTest::registerOpValidator qti.aisw
#
# [USER_INFO] QnnDsp <I> addClient done (1). status = 0x0
# [USER_INFO] QnnDsp <I> QnnDevice_create started. device = 0x1
# [USER_INFO] QnnDsp <I> QnnDevice_create done. status 0x0
# [USER_INFO] QnnDsp <I> QnnContext_create started. context 0x1
# [USER_INFO] QnnDsp <I> QnnContext_create done successfully
# [USER_INFO] QnnDsp <I> QnnGraph_create started. context 0x1, graph name: QnnGraph
# [USER_INFO] QnnDsp <I> QnnGraph_create done. graph QnnGraph, id 0x1
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 2816571830 for Tensor name Conv_0Conv_0Conv_0Conv_0_dilation
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 4182150695 for Tensor name Conv_0Conv_0Conv_0Conv_0_pad_amount
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 845747841 for Tensor name Conv_0Conv_0Conv_0Conv_0_stride
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 3633258352 for Tensor name input
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 2789887763 for Tensor name 2903
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 1921002488 for Tensor name 2904
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 1411501072 for Tensor name 2902
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_0:qnnOpCount_0:layerName_Conv_0 (qti.aisw::Conv2d). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 3074056268 for Tensor name 1757
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_1:qnnOpCount_1:layerName_Relu_1 (qti.aisw::Relu). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 750332145 for Tensor name Conv_2Conv_2Conv_2Conv_2_dilation
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 3748811758 for Tensor name Conv_2Conv_2Conv_2Conv_2_pad_amount
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 1036362023 for Tensor name Conv_2Conv_2Conv_2Conv_2_stride
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 2478529295 for Tensor name 2906
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 1641076748 for Tensor name 2907
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 2162927867 for Tensor name 2905
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_2:qnnOpCount_2:layerName_Conv_2 (qti.aisw::Conv2d). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 1461169214 for Tensor name 1760
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_3:qnnOpCount_3:layerName_Relu_3 (qti.aisw::Relu). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 3032329673 for Tensor name Conv_4Conv_4Conv_4Conv_4_dilation
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 3039770037 for Tensor name Conv_4Conv_4Conv_4Conv_4_pad_amount
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 758151629 for Tensor name Conv_4Conv_4Conv_4Conv_4_stride
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 3450365739 for Tensor name 2909
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 2797085840 for Tensor name 2910
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 1069802536 for Tensor name 2908
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_4:qnnOpCount_4:layerName_Conv_4 (qti.aisw::Conv2d). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 1145528266 for Tensor name 1763
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_5:qnnOpCount_5:layerName_Relu_5 (qti.aisw::Relu). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 1072037006 for Tensor name Conv_6Conv_6Conv_6Conv_6_dilation
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 2468079740 for Tensor name Conv_6Conv_6Conv_6Conv_6_pad_amount
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 580701803 for Tensor name Conv_6Conv_6Conv_6Conv_6_stride
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 1199789159 for Tensor name 2912
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 3051935588 for Tensor name 2913
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 1423157139 for Tensor name 2911
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_6:qnnOpCount_6:layerName_Conv_6 (qti.aisw::Conv2d). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 1907772374 for Tensor name 1766
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_7:qnnOpCount_7:layerName_Relu_7 (qti.aisw::Relu). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 2170081608 for Tensor name Conv_8Conv_8Conv_8Conv_8_dilation
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 1637218563 for Tensor name Conv_8Conv_8Conv_8Conv_8_pad_amount
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 215730201 for Tensor name Conv_8Conv_8Conv_8Conv_8_stride
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 2471047308 for Tensor name 2915
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 2149172088 for Tensor name 2916
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 1629664143 for Tensor name 2914
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_8:qnnOpCount_8:layerName_Conv_8 (qti.aisw::Conv2d). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 1174586003 for Tensor name Conv_9Conv_9Conv_9Conv_9_dilation
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 4034505887 for Tensor name Conv_9Conv_9Conv_9Conv_9_pad_amount
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 185439178 for Tensor name Conv_9Conv_9Conv_9Conv_9_stride
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 744586335 for Tensor name 2918
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 3725262684 for Tensor name 2919
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 1920090235 for Tensor name 2917
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_9:qnnOpCount_9:layerName_Conv_9 (qti.aisw::Conv2d). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 3068049226 for Tensor name 1771
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_10:qnnOpCount_10:layerName_Add_10 (qti.aisw::ElementWiseAdd). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 2777564350 for Tensor name 1772
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_11:qnnOpCount_11:layerName_Relu_11 (qti.aisw::Relu). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 1338925242 for Tensor name Conv_12Conv_12Conv_12Conv_12_dilation
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 1110759631 for Tensor name Conv_12Conv_12Conv_12Conv_12_pad_amount
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 68181279 for Tensor name Conv_12Conv_12Conv_12Conv_12_stride
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 1614024458 for Tensor name 2921
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 1935998206 for Tensor name 2922
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 2455735305 for Tensor name 2920
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_12:qnnOpCount_12:layerName_Conv_12 (qti.aisw::Conv2d). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 1900290133 for Tensor name 1775
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_13:qnnOpCount_13:layerName_Relu_13 (qti.aisw::Relu). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 3221097053 for Tensor name Conv_14Conv_14Conv_14Conv_14_dilation
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 1226999071 for Tensor name Conv_14Conv_14Conv_14Conv_14_pad_amount
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 355408830 for Tensor name Conv_14Conv_14Conv_14Conv_14_stride
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 1438980886 for Tensor name 2924
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 2813237269 for Tensor name 2925
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 2165276669 for Tensor name 2923
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_14:qnnOpCount_14:layerName_Conv_14 (qti.aisw::Conv2d). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 3463212166 for Tensor name 1778
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_15:qnnOpCount_15:layerName_Relu_15 (qti.aisw::Relu). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 323617199 for Tensor name Conv_16Conv_16Conv_16Conv_16_dilation
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 3010763776 for Tensor name Conv_16Conv_16Conv_16Conv_16_pad_amount
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 440018465 for Tensor name Conv_16Conv_16Conv_16Conv_16_stride
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 1184229602 for Tensor name 2927
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 411489478 for Tensor name 2928
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 3036572641 for Tensor name 2926
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_16:qnnOpCount_16:layerName_Conv_16 (qti.aisw::Conv2d). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 1369947575 for Tensor name 1781
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_17:qnnOpCount_17:layerName_Add_17 (qti.aisw::ElementWiseAdd). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 1123503683 for Tensor name 1782
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_18:qnnOpCount_18:layerName_Relu_18 (qti.aisw::Relu). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 203992219 for Tensor name Conv_19Conv_19Conv_19Conv_19_dilation
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 
pad_amount
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 2559934962 for Tensor name Conv_52Conv_52Conv_52Conv_52_stride
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 776734037 for Tensor name 2972
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 3693577814 for Tensor name 2973
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 1025308321 for Tensor name 2971
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_52:qnnOpCount_52:layerName_Conv_52 (qti.aisw::Conv2d). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 2812641230 for Tensor name 1832
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_53:qnnOpCount_53:layerName_Relu_53 (qti.aisw::Relu). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 2584567119 for Tensor name Conv_54Conv_54Conv_54Conv_54_dilation
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 3561873339 for Tensor name Conv_54Conv_54Conv_54Conv_54_pad_amount
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 2309670739 for Tensor name Conv_54Conv_54Conv_54Conv_54_stride
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 4203110846 for Tensor name 2975
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 3923153482 for Tensor name 2976
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 149807805 for Tensor name 2974
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_54:qnnOpCount_54:layerName_Conv_54 (qti.aisw::Conv2d). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 1936661285 for Tensor name 1835
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_55:qnnOpCount_55:layerName_Add_55 (qti.aisw::ElementWiseAdd). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 1614801105 for Tensor name 1836
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_56:qnnOpCount_56:layerName_Relu_56 (qti.aisw::Relu). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 1625510724 for Tensor name Conv_57Conv_57Conv_57Conv_57_dilation
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 3519476051 for Tensor name Conv_57Conv_57Conv_57Conv_57_pad_amount
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 63135611 for Tensor name Conv_57Conv_57Conv_57Conv_57_stride
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 1169042797 for Tensor name 2978
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 3083185774 for Tensor name 2979
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 465375561 for Tensor name 2977
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_57:qnnOpCount_57:layerName_Conv_57 (qti.aisw::Conv2d). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 1043125493 for Tensor name 1839
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_58:qnnOpCount_58:layerName_Relu_58 (qti.aisw::Relu). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 702282633 for Tensor name Conv_59Conv_59Conv_59Conv_59_dilation
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 1035752428 for Tensor name Conv_59Conv_59Conv_59Conv_59_pad_amount
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 782823334 for Tensor name Conv_59Conv_59Conv_59Conv_59_stride
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 3664116828 for Tensor name 2981
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 3375697832 for Tensor name 2982
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 672038751 for Tensor name 2980
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_59:qnnOpCount_59:layerName_Conv_59 (qti.aisw::Conv2d). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 3720918667 for Tensor name 1842
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_60:qnnOpCount_60:layerName_Add_60 (qti.aisw::ElementWiseAdd). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 799225224 for Tensor name 1843
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_61:qnnOpCount_61:layerName_Relu_61 (qti.aisw::Relu). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 4082004637 for Tensor name Conv_62Conv_62Conv_62Conv_62_dilation
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 3065510288 for Tensor name Conv_62Conv_62Conv_62Conv_62_pad_amount
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 846937723 for Tensor name Conv_62Conv_62Conv_62Conv_62_stride
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 4019513408 for Tensor name 2984
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 503278403 for Tensor name 2985
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 996052139 for Tensor name 2983
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_62:qnnOpCount_62:layerName_Conv_62 (qti.aisw::Conv2d). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 441590164 for Tensor name 1846
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_63:qnnOpCount_63:layerName_Relu_63 (qti.aisw::Relu). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 58595450 for Tensor name Conv_64Conv_64Conv_64Conv_64_dilation
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 3181487168 for Tensor name Conv_64Conv_64Conv_64Conv_64_pad_amount
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 591689946 for Tensor name Conv_64Conv_64Conv_64Conv_64_stride
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 4240710580 for Tensor name 2987
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 2732009360 for Tensor name 2988
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 246388919 for Tensor name 2986
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_64:qnnOpCount_64:layerName_Conv_64 (qti.aisw::Conv2d). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 1145118128 for Tensor name 1849
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_65:qnnOpCount_65:layerName_Add_65 (qti.aisw::ElementWiseAdd). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 793861643 for Tensor name 1850
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_66:qnnOpCount_66:layerName_Relu_66 (qti.aisw::Relu). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 4186969713 for Tensor name Conv_67Conv_67Conv_67Conv_67_dilation
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 3089795752 for Tensor name Conv_67Conv_67Conv_67Conv_67_pad_amount
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 2838356210 for Tensor name Conv_67Conv_67Conv_67Conv_67_stride
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 1001187112 for Tensor name 2990
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 3385287723 for Tensor name 2991
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 1354540179 for Tensor name 2989
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_67:qnnOpCount_67:layerName_Conv_67 (qti.aisw::Conv2d). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 1006743039 for Tensor name 1853
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_68:qnnOpCount_68:layerName_Relu_68 (qti.aisw::Relu). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 2963848892 for Tensor name Conv_69Conv_69Conv_69Conv_69_dilation
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 1414539287 for Tensor name Conv_69Conv_69Conv_69Conv_69_pad_amount
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 2219200559 for Tensor name Conv_69Conv_69Conv_69Conv_69_stride
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 687609052 for Tensor name 2993
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 4231426103 for Tensor name 2994
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 3667367903 for Tensor name 2992
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_69:qnnOpCount_69:layerName_Conv_69 (qti.aisw::Conv2d). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 166771171 for Tensor name 1856
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# ...
# [USER_INFO] QnnDsp <I> create Tensor Id 1167081602 for Tensor name Conv_744Conv_744Conv_744Conv_744_stride
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 3915789114 for Tensor name 3755
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 4197892302 for Tensor name 3756
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 453881913 for Tensor name 3754
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_719:qnnOpCount_719:layerName_Conv_744 (qti.aisw::Conv2d). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 2039775147 for Tensor name 2860
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_720:qnnOpCount_720:layerName_Add_745 (qti.aisw::ElementWiseAdd). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 2348809384 for Tensor name 2861
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_721:qnnOpCount_721:layerName_Relu_746 (qti.aisw::Relu). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 1489074156 for Tensor name Conv_747Conv_747Conv_747Conv_747_dilation
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 800918259 for Tensor name Conv_747Conv_747Conv_747Conv_747_pad_amount
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 16508710 for Tensor name Conv_747Conv_747Conv_747Conv_747_stride
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 1447985129 for Tensor name 3758
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 2753953002 for Tensor name 3759
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 140329933 for Tensor name 3757
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_722:qnnOpCount_722:layerName_Conv_747 (qti.aisw::Conv2d). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 3188648116 for Tensor name 2864
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_723:qnnOpCount_723:layerName_Relu_748 (qti.aisw::Relu). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 2301669467 for Tensor name Conv_749Conv_749Conv_749Conv_749_dilation
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 4179277842 for Tensor name Conv_749Conv_749Conv_749Conv_749_pad_amount
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 1762380415 for Tensor name Conv_749Conv_749Conv_749Conv_749_stride
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 437980348 for Tensor name 3761
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 155975496 for Tensor name 3762
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 3899690943 for Tensor name 3760
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_724:qnnOpCount_724:layerName_Conv_749 (qti.aisw::Conv2d). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 2908625728 for Tensor name 2867
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_725:qnnOpCount_725:layerName_Add_750 (qti.aisw::ElementWiseAdd). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 4081919844 for Tensor name 2868
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_726:qnnOpCount_726:layerName_Relu_751 (qti.aisw::Relu). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 3361442491 for Tensor name Conv_752Conv_752Conv_752Conv_752_dilation
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 3645130511 for Tensor name Conv_752Conv_752Conv_752Conv_752_pad_amount
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 277931375 for Tensor name Conv_752Conv_752Conv_752Conv_752_stride
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 803870880 for Tensor name 3764
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 3716258723 for Tensor name 3765
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 4213210187 for Tensor name 3763
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_727:qnnOpCount_727:layerName_Conv_752 (qti.aisw::Conv2d). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 2556257503 for Tensor name 2871
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_728:qnnOpCount_728:layerName_Relu_753 (qti.aisw::Relu). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 3039831112 for Tensor name Conv_754Conv_754Conv_754Conv_754_dilation
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 2802497026 for Tensor name Conv_754Conv_754Conv_754Conv_754_pad_amount
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 2588387879 for Tensor name Conv_754Conv_754Conv_754Conv_754_stride
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 1018882900 for Tensor name 3767
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 1655297904 for Tensor name 3768
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 3469830231 for Tensor name 3766
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_729:qnnOpCount_729:layerName_Conv_754 (qti.aisw::Conv2d). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 2913759427 for Tensor name 2874
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_730:qnnOpCount_730:layerName_Add_755 (qti.aisw::ElementWiseAdd). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 1606939584 for Tensor name 2875
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_731:qnnOpCount_731:layerName_Relu_756 (qti.aisw::Relu). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 158582857 for Tensor name Conv_757Conv_757Conv_757Conv_757_dilation
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 450622972 for Tensor name Conv_757Conv_757Conv_757Conv_757_pad_amount
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 3744206211 for Tensor name Conv_757Conv_757Conv_757Conv_757_stride
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 4224849864 for Tensor name 3770
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 163157195 for Tensor name 3771
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 2428654707 for Tensor name 3769
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_732:qnnOpCount_732:layerName_Conv_757 (qti.aisw::Conv2d). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 1819581910 for Tensor name 2882
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_733:qnnOpCount_733:layerName_Resize_759 (qti.aisw::ResizeNearestNeighbor). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 2652839637 for Tensor name 2883
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_734:qnnOpCount_734:layerName_Add_760 (qti.aisw::ElementWiseAdd). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 2261755477 for Tensor name Conv_761Conv_761Conv_761Conv_761_dilation
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 993920480 for Tensor name Conv_761Conv_761Conv_761Conv_761_pad_amount
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 812583893 for Tensor name Conv_761Conv_761Conv_761Conv_761_stride
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 3900892220 for Tensor name 3773
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 1011384535 for Tensor name 3774
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 451503935 for Tensor name 3772
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_735:qnnOpCount_735:layerName_Conv_761 (qti.aisw::Conv2d). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 2666362198 for Tensor name 2890
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_736:qnnOpCount_736:layerName_Resize_763 (qti.aisw::ResizeNearestNeighbor). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 1820784213 for Tensor name 2891
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_737:qnnOpCount_737:layerName_Add_764 (qti.aisw::ElementWiseAdd). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 3498218231 for Tensor name Conv_765Conv_765Conv_765Conv_765_dilation
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 1867162646 for Tensor name Conv_765Conv_765Conv_765Conv_765_pad_amount
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 3272245669 for Tensor name Conv_765Conv_765Conv_765Conv_765_stride
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 3715362848 for Tensor name 3776
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 790131491 for Tensor name 3777
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 3458401236 for Tensor name 3775
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_738:qnnOpCount_738:layerName_Conv_765 (qti.aisw::Conv2d). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 338963865 for Tensor name 2898
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_739:qnnOpCount_739:layerName_Resize_767 (qti.aisw::ResizeNearestNeighbor). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 3865030298 for Tensor name 2899
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_740:qnnOpCount_740:layerName_Add_768 (qti.aisw::ElementWiseAdd). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 3038428391 for Tensor name 2900
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_741:qnnOpCount_741:layerName_Relu_769 (qti.aisw::Relu). status 0x0
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 1075343264 for Tensor name Conv_770Conv_770Conv_770Conv_770_dilation
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 2578704874 for Tensor name Conv_770Conv_770Conv_770Conv_770_pad_amount
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 3546383340 for Tensor name Conv_770Conv_770Conv_770Conv_770_stride
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 345894614 for Tensor name final_layer.weight
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 648126922 for Tensor name final_layer.bias
# [USER_INFO] QnnDsp <I> QnnTensor_createGraphTensor graph 1
# [USER_INFO] QnnDsp <I> create Tensor Id 2905577907 for Tensor name output
# [USER_INFO] QnnDsp <I> QnnGraph_addNode started. graph 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_addNode done. Graph QnnGraph added op dlcId_742:qnnOpCount_742:layerName_Conv_770 (qti.aisw::Conv2d). status 0x0
# [USER_INFO] No valid context cache found. Creating graph from scratch.
# [USER_INFO] QnnDsp <I> QnnGraph_finalize started, graph = 0x1
# [USER_INFO] QnnDsp <I> QnnGraph_finalize done. Graph QnnGraph. status = 0x0
# [USER_INFO] QnnDsp <I> QnnContext_getBinarySize started. context 0x1
# [USER_INFO] QnnDsp <I> QnnContext_getBinarySize done, status 0x0
# [USER_INFO] QnnDsp <I> QnnContext_getBinary started. context 0x1
# [USER_INFO] QnnDsp <I> QnnContext_getBinary done. status 0x0
# [USER_INFO] BackendTerminate triggered
# [USER_INFO] QnnDsp <I> QnnContext_free started. contextId 1
# [USER_INFO] QnnDsp <I> QnnContext_free done. status 0x0
# [USER_INFO] QnnDsp <I> QnnDevice_free started. device = 0x1
# [USER_INFO] QnnDsp <I> QnnDevice_free done. status 0x0
# [USER_INFO] QnnDsp <I> terminateClient started. 0x1
# [USER_INFO] QnnDsp <I> terminateClient done. status 0x0
# [USER_INFO] QnnDsp <I> terminateClient started. logger = 0x1
# [USER_INFO] QnnDsp <I> Qnn log terminated
# [INFO] SNPE HTP Offline Prepare: Successfully created cache for SM8550
# [INFO] SNPE HTP Offline Prepare: Saved cached DLC to app/src/main/assets/hrnet_axis_int8_cached.dlc
# [USER_INFO] BackendTerminate triggered
# [USER_INFO] Cleaning up backend manager resources
# [USER_INFO] Cleaning up Contexts
# [INFO] DebugLog shutting down.
