# %% [markdown]
# # Setting Up All Artifacts details

# %%
import os
os.environ['SNPE_ROOT']="/local/mnt/workspace/snpe/2.16.0.231029/"#set up your snpe path here.
os.environ['RAW_FILE_FOLDER']="input/raw"
os.environ['DLC32']="models/sesr_fp32.dlc"
os.environ['DLC8']="models/sesr_w8a8.dlc"
os.environ['TARGET_INPUT_LIST']="input/input.txt"
os.environ['ONDEVICE_FOLDER']="sesr"
os.environ['DEVICE_HOST']="localhost"
os.environ['DEVICE_ID']="2dce6316" #fill your device-id. Use command "adb devices" to get devices names. example :"e18d5d0"
os.environ['SNPE_TARGET_ARCH']="aarch64-android"
os.environ['SNPE_TARGET_STL']="libc++_shared.so"

# %%
import cv2
import glob
import os
import numpy as np
import torch

# %%
os.makedirs('utils', exist_ok= True)

# %%
# %%bash
# git clone https://github.com/quic/aimet-model-zoo/
# Out:
# Cloning into 'aimet-model-zoo'...

# %%
# %%bash
# cp -r SESR.patch aimet-model-zoo
# cd aimet-model-zoo
# git apply SESR.patch

# %%
# %%bash
# cp -r aimet-model-zoo/aimet_zoo_torch/common/super_resolution/ utils/
# cp -r aimet-model-zoo/aimet_zoo_torch/common/downloader.py utils/super_resolution/
# cp -r aimet-model-zoo/aimet_zoo_torch/sesr/model/ utils/
# rm -rf aimet-model-zoo/

# %%
# %%bash
# cd utils
# touch __init__.py

# %%
from utils.model.model_definition import SESR
from utils.super_resolution.imresize import imresize

# %%
model_fp32 = SESR("sesr_m11_4x_w8a8",scaling_factor=4)
model_fp32.from_pretrained(quantized=False)

# %%
os.makedirs('models', exist_ok= True)
os.makedirs('output', exist_ok= True)

# %%
import os
dummy_input = torch.randn(1,3, 128, 128).type(torch.FloatTensor).to('cpu')
torch.onnx.export(model_fp32, dummy_input, "./models/sesr.onnx",opset_version=11)

# %%
# %%bash
# source $SNPE_ROOT/bin/envsetup.sh
# snpe-onnx-to-dlc --input_network models/sesr.onnx --output_path models/sesr_fp32.dlc
# Out:
# [INFO] AISW SDK environment set
# [INFO] SNPE_ROOT: /local/mnt/workspace/snpe/2.16.0.231029
# 2023-11-24 14:15:02,372 - 235 - INFO - Successfully simplified the onnx model in child process
# 2023-11-24 14:15:02,386 - 235 - INFO - Successfully receive the simplified onnx model in main process
# 2023-11-24 14:15:02,393 - 235 - INFO - Successfully run shape inference in child process
# 2023-11-24 14:15:02,403 - 235 - INFO - Successfully receive the inferred model in main process
# 2023-11-24 14:15:02,515 - 235 - INFO - INFO_INITIALIZATION_SUCCESS:
# 2023-11-24 14:15:02,524 - 235 - INFO - INFO_CONVERSION_SUCCESS: Conversion completed successfully
# 2023-11-24 14:15:02,527 - 235 - INFO - INFO_WRITE_SUCCESS:

# %% [markdown]
# # Download dataset
# <ul>
#     <li>  Dataset link wget https://figshare.com/ndownloader/files/38256855  </li>
# <li>Below block will automatically download datsest, but in case if it fails please download from above link.</li>
#     <li> Recommended, to comment below code, if already downloaded dataset once.</li>
#     <ul>

# %%
# %%bash
# wget https://figshare.com/ndownloader/files/38256855
#  'input/Set14/img_009_SRF_2_HR.png',
#  'input/Set14/img_010_SRF_2_HR.png',
#  'input/Set14/img_011_SRF_2_HR.png',
#  'input/Set14/img_012_SRF_2_HR.png',
#  'input/Set14/img_013_SRF_2_HR.png',
#  'input/Set14/img_014_SRF_2_HR.png']

# %%
RGB_WEIGHTS = torch.FloatTensor([65.481, 128.553, 24.966])
def preprocess(img, scaling_factor=2):
    lr_img, hr_img = create_hr_lr_pair(img, scaling_factor)
    return lr_img, hr_img

# %%
def create_hr_lr_pair(img, scaling_factor=2):
    height, width = img.shape[0:2]

    # Take the largest possible center-crop of it such that its dimensions are perfectly divisible by the scaling factor
    x_remainder = width % (scaling_factor)
    y_remainder = height % (scaling_factor)
    left = x_remainder // 2
    top = y_remainder // 2
    right = left + (width - x_remainder)
    bottom = top + (height - y_remainder)
    hr_img = img[top:bottom, left:right]

    hr_height, hr_width = hr_img.shape[0:2]

    hr_img = np.array(hr_img, dtype='float32')
    lr_img = imresize(hr_img, 1. / scaling_factor)  # equivalent to matlab's imresize
    flag=0
    lr_img = np.uint8(np.clip(lr_img, 0., 255.))  # this is to simulate matlab's imwrite operation
    hr_img = np.uint8(hr_img)
    lr_height, lr_width = lr_img.shape[0:2]

    # Sanity check
    assert hr_width == lr_width * scaling_factor and hr_height == lr_height * scaling_factor
    lr_img = convert_image(lr_img, source='array', target='[0, 1]')
    hr_img = convert_image(hr_img, source='array', target='[0, 1]')

    return lr_img, hr_img

# %%
def convert_image(img, source, target):
    if source == 'array':
        img = torch.from_numpy(img.transpose((2, 0, 1))).contiguous()#chw
        img = img.to(dtype=torch.float32).div(255)
    elif source == '[0, 1]':
        img = torch.clamp(img, 0, 1)  # useful to post-process output of models that can overspill
    
    if target == '[0, 1]':
        pass  # already in [0, 1]
    elif target == 'y-channel':
        img = torch.matmul(img.permute(0, 2, 3, 1), RGB_WEIGHTS.to(img.device)) + 16.
    
    return img

# %%
def post_process(img):
    img = img.detach().cpu().numpy()
    img = np.clip(255. * img, 0., 255.)
    img = np.uint8(img)
    img = img.transpose(1, 2, 0)#hwc
    return img

# %%
def load_dataset(test_images_dir, scaling_factor=2):
    # Input images for the model
    INPUTS_LR = []
    # Post-processed images for visualization
    IMAGES_LR = []
    IMAGES_HR = []  
    # Load the test images
    count=0
    img_paths =  glob.glob(os.path.join(test_images_dir, '*'))
    img_paths = sorted(img_paths)
    for img_path in img_paths:
        img = cv2.resize(cv2.imread(img_path),[512,512],interpolation=cv2.INTER_CUBIC)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        lr_img, hr_img = preprocess(img, scaling_factor)#chw
        INPUTS_LR.append(lr_img)#chw
        IMAGES_LR.append(post_process(lr_img))#hwc
        IMAGES_HR.append(post_process(hr_img))#hwc

    return INPUTS_LR, IMAGES_LR, IMAGES_HR

# %%
test_images_dir = "input/Set14"
INPUTS_LR, IMAGES_LR, IMAGES_HR = load_dataset(test_images_dir, scaling_factor=4)
for i, img_lr in enumerate(INPUTS_LR):
    img_lr = img_lr.cpu().detach().numpy()
    img_lr = img_lr.astype(np.float32)
    fid = open("input/raw/img"+str(i)+ ".raw", 'wb')
    img_lr.tofile(fid)
    fid.close()

# %%
import matplotlib.pyplot as plt
plt.imshow(IMAGES_LR[0])
plt.imshow(IMAGES_HR[0])

# %%
with open("input/input.txt", "w") as f:
    for i in range(14):
        file_path = f"./raw/img{i}.raw"
        f.write(file_path + "\n")

# %%
# %%bash
# source $SNPE_ROOT/bin/envsetup.sh
# cd input
# snpe-dlc-quantize --input_dlc ../models/sesr_fp32.dlc --input_list input.txt --use_enhanced_quantizer --use_adjusted_weights_quantizer --axis_quant --output_dlc ../models/sesr_w8a8.dlc
# Out:
# [INFO] AISW SDK environment set
# [INFO] SNPE_ROOT: /local/mnt/workspace/snpe/2.16.0.231029
# [INFO] InitializeStderr: DebugLog initialized.
# [INFO] Processed command-line arguments
# [INFO] Quantized parameters
# [INFO] Generated activations
# [INFO] Saved quantized dlc to: ../models/sesr_w8a8.dlc
# [INFO] DebugLog shutting down.
#      0.0ms [  INFO ] Inferences will run in sync mode
#      0.1ms [  INFO ] Initializing logging in the backend. Callback: [0xcf3a80], Log Level: [3]
#      0.1ms [  INFO ] No BackendExtensions lib provided;initializing NetRunBackend Interface
#      0.1ms [WARNING] Unable to find a device with NetRunDeviceKeyDefault in Library NetRunBackendLibKeyDefault
#      0.1ms [  INFO ] Entering QuantizeRuntimeApp flow
#    435.7ms [  INFO ] cleaning up resources for input tensors
#    435.7ms [  INFO ] cleaning up resources for output tensors
#    715.1ms [  INFO ] cleaning up resources for input tensors
#    715.1ms [  INFO ] cleaning up resources for output tensors
#    986.1ms [  INFO ] cleaning up resources for input tensors
#    986.1ms [  INFO ] cleaning up resources for output tensors
#   1253.9ms [  INFO ] cleaning up resources for input tensors
#   1253.9ms [  INFO ] cleaning up resources for output tensors
#   1548.1ms [  INFO ] cleaning up resources for input tensors
#   1548.1ms [  INFO ] cleaning up resources for output tensors
#   1831.7ms [  INFO ] cleaning up resources for input tensors
#   1831.7ms [  INFO ] cleaning up resources for output tensors
#   2122.6ms [  INFO ] cleaning up resources for input tensors
#   2122.6ms [  INFO ] cleaning up resources for output tensors
#   2401.9ms [  INFO ] cleaning up resources for input tensors
#   2401.9ms [  INFO ] cleaning up resources for output tensors
#   2685.0ms [  INFO ] cleaning up resources for input tensors
#   2685.0ms [  INFO ] cleaning up resources for output tensors
#   2965.3ms [  INFO ] cleaning up resources for input tensors
#   2965.3ms [  INFO ] cleaning up resources for output tensors
#   3254.4ms [  INFO ] cleaning up resources for input tensors
#   3254.5ms [  INFO ] cleaning up resources for output tensors
#   3515.7ms [  INFO ] cleaning up resources for input tensors
#   3515.7ms [  INFO ] cleaning up resources for output tensors
#   3797.4ms [  INFO ] cleaning up resources for input tensors
#   3797.4ms [  INFO ] cleaning up resources for output tensors
#   4093.7ms [  INFO ] cleaning up resources for input tensors
#   4093.7ms [  INFO ] cleaning up resources for output tensors
#   4257.8ms [  INFO ] Freeing graphsInfo

# %% [markdown]
# # Post-process model output

# %%
def post_process_sr(img):
#     img = img.detach().cpu().numpy()
    img = np.fromfile(img, np.float32)
    img = img.reshape((3,512, 512)).astype(np.float32)
    img = np.clip(255. * img, 0., 255.)
    img = np.uint8(img)
    img = img.transpose(1, 2, 0)#hwc
    return img

# %% [markdown]
# # Method to calcualte PSNR

# %%
def compute_psnr(img_pred, img_true, data_range=255., eps=1e-8):
    """
    Compute PSNR between super-resolved and original images.
    
    :param img_pred:
        The super-resolved image obtained from the model
    :param img_true:
        The original high-res image
    :param data_range:
        Default = 255
    :param eps:
        Default = 1e-8
    :return:
        PSNR value
    """
    err = (img_pred - img_true) ** 2
    err = err.mean(dim=-1).mean(dim=-1)
    return 10. * torch.log10((data_range ** 2) / (err + eps))

# %%
def evaluate_psnr(y_pred, y_true):
    """
    Evaluate individual PSNR metric for each super-res and actual high-res image-pair.
    
    :param y_pred:
        The super-resolved image from the model
    :param y_true:
        The original high-res image
    :return:
        The evaluated PSNR metric for the image-pair
    """
    y_pred = y_pred.transpose(2, 0, 1)[None] / 255.
    y_true = y_true.transpose(2, 0, 1)[None] / 255.

    sr_img = convert_image(torch.FloatTensor(y_pred),
                           source='[0, 1]',
                           target='y-channel')
    hr_img = convert_image(torch.FloatTensor(y_true),
                           source='[0, 1]',
                           target='y-channel')
    return compute_psnr(sr_img, hr_img)

# %%
def evaluate_average_psnr(sr_images, hr_images):
    """
    Evaluate the avg PSNR metric for all test-set super-res and high-res images.

    :param sr_images:
        The list of super-resolved images obtained from the model for the given test-images
    :param hr_images:
        The list of original high-res test-images
    :return:
        Average PSNR metric for all super-resolved and high-res test-set image-pairs
    """
    psnr = []
    for sr_img, hr_img in zip(sr_images, hr_images):
        psnr.append(evaluate_psnr(sr_img, hr_img))

    # Convert the list of tensor values to a tensor array
    psnr_tensor = torch.cat(psnr)
   # Calculate the mean of the tensor array
    average_psnr = torch.mean(psnr_tensor)
    return average_psnr

# %% [markdown]
# # Creating Bin and Lib Folder on Device

# %%
# %%bash
# export DEVICE_SHELL="adb -H $DEVICE_HOST -s $DEVICE_ID"
# $DEVICE_SHELL shell "mkdir -p /data/local/tmp/snpeexample/$SNPE_TARGET_ARCH/bin" && $DEVICE_SHELL shell "mkdir -p /data/local/tmp/snpeexample/$SNPE_TARGET_ARCH/lib" && $DEVICE_SHELL shell "mkdir -p /data/local/tmp/snpeexample/dsp/lib"

# %% [markdown]
# # Pushing all Lib and Bin files onto Device

# %%
# %%bash
# export DEVICE_SHELL="adb -H $DEVICE_HOST -s $DEVICE_ID"
# $DEVICE_SHELL push $SNPE_ROOT/lib/$SNPE_TARGET_ARCH/$SNPE_TARGET_STL /data/local/tmp/snpeexample/$SNPE_TARGET_ARCH/lib
# $DEVICE_SHELL push $SNPE_ROOT/bin/$SNPE_TARGET_ARCH/snpe-net-run /data/local/tmp/snpeexample/$SNPE_TARGET_ARCH/bin
# $DEVICE_SHELL push $SNPE_ROOT/lib/hexagon-v75/unsigned/*.so /data/local/tmp/snpeexample/dsp/lib
# $DEVICE_SHELL push $SNPE_ROOT/lib/$SNPE_TARGET_ARCH/*.so /data/local/tmp/snpeexample/$SNPE_TARGET_ARCH/lib
# Out:
# /local/mnt/workspace/aditya/qaisw-v2.15.1.230926150623_62883/lib/aarch64-android/libc++_shared.so: 1 file pushed. 36.3 MB/s (1027408 bytes in 0.027s)
# /local/mnt/workspace/aditya/qaisw-v2.15.1.230926150623_62883/bin/aarch64-android/snpe-net-run: 1 file pushed. 39.4 MB/s (389784 bytes in 0.009s)
# /local/mnt/workspace/aditya/qaisw-v2.15.1.230926150623_62883/lib/hexagon-v75/unsigned/libCalculator_skel.so: 1 file pushed. 0.6 MB/s (5484 bytes in 0.009s)
# /local/mnt/workspace/aditya/qaisw-v2.15.1.230926150623_62883/lib/hexagon-v75/unsigned/libSnpeHtpV75Skel.so: 1 file pushed. 55.6 MB/s (10816112 bytes in 0.186s)
# 2 files pushed. 51.7 MB/s (10821596 bytes in 0.200s)
# /local/mnt/workspace/aditya/qaisw-v2.15.1.230926150623_62883/lib/aarch64-android/libcalculator_htp.so: 1 file pushed. 0.8 MB/s (6416 bytes in 0.008s)
# /local/mnt/workspace/aditya/qaisw-v2.15.1.230926150623_62883/lib/aarch64-android/libcalculator.so: 1 file pushed. 1.5 MB/s (6368 bytes in 0.004s)
# /local/mnt/workspace/aditya/qaisw-v2.15.1.230926150623_62883/lib/aarch64-android/libc++_shared.so: 1 file pushed. 33.8 MB/s (1027408 bytes in 0.029s)
# /local/mnt/workspace/aditya/qaisw-v2.15.1.230926150623_62883/lib/aarch64-android/libhta_hexagon_runtime_snpe.so: 1 file pushed. 60.6 MB/s (2777480 bytes in 0.044s)
# /local/mnt/workspace/aditya/qaisw-v2.15.1.230926150623_62883/lib/aarch64-android/libPlatformValidatorShared.so: 1 file pushed. 109.7 MB/s (9404168 bytes in 0.082s)
# /local/mnt/workspace/aditya/qaisw-v2.15.1.230926150623_62883/lib/aarch64-android/libSnpeDspV66Stub.so: 1 file pushed. 66.1 MB/s (931672 bytes in 0.013s)
# /local/mnt/workspace/aditya/qaisw-v2.15.1.230926150623_62883/lib/aarch64-android/libSnpeHta.so: 1 file pushed. 67.8 MB/s (533536 bytes in 0.008s)
# /local/mnt/workspace/aditya/qaisw-v2.15.1.230926150623_62883/lib/aarch64-android/libSnpeHtpPrepare.so: 1 file pushed. 154.7 MB/s (24585192 bytes in 0.152s)
# /local/mnt/workspace/aditya/qaisw-v2.15.1.230926150623_62883/lib/aarch64-android/libSnpeHtpV68Stub.so: 1 file pushed. 8.4 MB/s (62520 bytes in 0.007s)
# /local/mnt/workspace/aditya/qaisw-v2.15.1.230926150623_62883/lib/aarch64-android/libSnpeHtpV69Stub.so: 1 file pushed. 11.3 MB/s (63432 bytes in 0.005s)
# /local/mnt/workspace/aditya/qaisw-v2.15.1.230926150623_62883/lib/aarch64-android/libSnpeHtpV73Stub.so: 1 file pushed. 14.6 MB/s (69656 bytes in 0.005s)
# /local/mnt/workspace/aditya/qaisw-v2.15.1.230926150623_62883/lib/aarch64-android/libSnpeHtpV75Stub.so: 1 file pushed. 15.5 MB/s (71760 bytes in 0.004s)
# /local/mnt/workspace/aditya/qaisw-v2.15.1.230926150623_62883/lib/aarch64-android/libSNPE.so: 1 file pushed. 126.1 MB/s (11849032 bytes in 0.090s)
# 13 files pushed. 107.9 MB/s (51388640 bytes in 0.454s)

# %% [markdown]
# # Pushing Artifacts on to Device

# %%
# %%bash
# export DEVICE_SHELL="adb -H $DEVICE_HOST -s $DEVICE_ID"
# $DEVICE_SHELL shell "mkdir -p /data/local/tmp/$ONDEVICE_FOLDER"

# %%
# %%bash
# #find ./raw -name *.raw > list.txt
# export DEVICE_SHELL="adb -H $DEVICE_HOST -s $DEVICE_ID"
# $DEVICE_SHELL push $DLC32 /data/local/tmp/$ONDEVICE_FOLDER
# $DEVICE_SHELL push $DLC8 /data/local/tmp/$ONDEVICE_FOLDER
# $DEVICE_SHELL push $RAW_FILE_FOLDER /data/local/tmp/$ONDEVICE_FOLDER
# $DEVICE_SHELL push $TARGET_INPUT_LIST /data/local/tmp/$ONDEVICE_FOLDER
# Out:
# models/sesr_fp32.dlc: 1 file pushed. 48.2 MB/s (2439182 bytes in 0.048s)
# models/sesr_w8a8.dlc: 1 file pushed. 24.5 MB/s (665452 bytes in 0.026s)
# input/raw/: 14 files pushed. 27.2 MB/s (2752512 bytes in 0.097s)
# input/input.txt: 1 file pushed. 0.1 MB/s (214 bytes in 0.003s)

# %% [markdown]
# # Inferencing 8 bit DLC on DSP Runtime
# Give name of DLC in OUTPUT_DLC_QUANTIZED8 and ondevice folder

# %%
# %%bash
# export DEVICE_SHELL="adb -H $DEVICE_HOST -s $DEVICE_ID"
# $DEVICE_SHELL shell
# export LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/data/local/tmp/snpeexample/aarch64-android/lib
# export PATH=$PATH:/data/local/tmp/snpeexample/aarch64-android/bin
# export ADSP_LIBRARY_PATH="/data/local/tmp/snpeexample/dsp/lib;/system/lib/rfsa/adsp;/system/vendor/lib/rfsa/adsp;/dsp"
# export OUTPUT_FOLDER=OUTPUT_8b_DSP
# export OUTPUT_DLC_QUANTIZED8=sesr_w8a8.dlc
# export ONDEVICE_FOLDER="sesr"
# cd /data/local/tmp/$ONDEVICE_FOLDER &&
# snpe-net-run --container $OUTPUT_DLC_QUANTIZED8 --input_list input.txt --output_dir $OUTPUT_FOLDER --use_dsp
# Out:
# -------------------------------------------------------------------------------
# Model String: N/A
# SNPE v2.15.1.230926150623_62883
# -------------------------------------------------------------------------------
# Processing DNN input(s):
# ./raw/img0.raw
# Processing DNN input(s):
# ./raw/img1.raw
# Processing DNN input(s):
# ./raw/img2.raw
# Processing DNN input(s):
# ./raw/img3.raw
# Processing DNN input(s):
# ./raw/img4.raw
# Processing DNN input(s):
# ./raw/img5.raw
# Processing DNN input(s):
# ./raw/img6.raw
# Processing DNN input(s):
# ./raw/img7.raw
# Processing DNN input(s):
# ./raw/img8.raw
# Processing DNN input(s):
# ./raw/img9.raw
# Processing DNN input(s):
# ./raw/img10.raw
# Processing DNN input(s):
# ./raw/img11.raw
# Processing DNN input(s):
# ./raw/img12.raw
# Processing DNN input(s):
# ./raw/img13.raw
# Successfully executed!

# %% [markdown]
# # Inferencing 32b DLC on CPU Runtime
# Give name of DLC in OUTPUT_DLC_32 and ondevice folder

# %%
# %%bash
# export DEVICE_SHELL="adb -H $DEVICE_HOST -s $DEVICE_ID"
# $DEVICE_SHELL shell
# export LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/data/local/tmp/snpeexample/aarch64-android/lib
# export PATH=$PATH:/data/local/tmp/snpeexample/aarch64-android/bin
# export OUTPUT_FOLDER=OUTPUT_32b_CPU
# export OUTPUT_DLC_32=sesr_fp32.dlc
# export ONDEVICE_FOLDER="sesr"
# cd /data/local/tmp/$ONDEVICE_FOLDER &&
# snpe-net-run --container $OUTPUT_DLC_32 --input_list input.txt --output_dir $OUTPUT_FOLDER
# Out:
# -------------------------------------------------------------------------------
# Model String: N/A
# SNPE v2.15.1.230926150623_62883
# -------------------------------------------------------------------------------
# Processing DNN input(s):
# ./raw/img0.raw
# WARNING: Failed to set thread affinity for cpuset 80. errno = 22. Setting the thread affinity to cpuset fc instead.
# WARNING: Failed to set thread affinity for cpuset 80. errno = 22. Setting the thread affinity to cpuset fc instead.
# WARNING: Failed to set thread affinity for cpuset 80. errno = 22. Setting the thread affinity to cpuset fc instead.
# WARNING: Failed to set thread affinity for cpuset 80. errno = 22. Setting the thread affinity to cpuset fc instead.
# WARNING: Failed to set thread affinity for cpuset 80. errno = 22. Setting the thread affinity to cpuset fc instead.
# WARNING: Failed to set thread affinity for cpuset 80. errno = 22. Setting the thread affinity to cpuset fc instead.
# WARNING: Failed to set thread affinity for cpuset 80. errno = 22. Setting the thread affinity to cpuset fc instead.
# WARNING: Failed to set thread affinity for cpuset 80. errno = 22. Setting the thread affinity to cpuset fc instead.
# WARNING: Failed to set thread affinity for cpuset 80. errno = 22. Setting the thread affinity to cpuset fc instead.
# WARNING: Failed to set thread affinity for cpuset 80. errno = 22. Setting the thread affinity to cpuset fc instead.
# WARNING: Failed to set thread affinity for cpuset 80. errno = 22. Setting the thread affinity to cpuset fc instead.
# WARNING: Failed to set thread affinity for cpuset 80. errno = 22. Setting the thread affinity to cpuset fc instead.
# WARNING: Failed to set thread affinity for cpuset 80. errno = 22. Setting the thread affinity to cpuset fc instead.
# WARNING: Failed to set thread affinity for cpuset 80. errno = 22. Setting the thread affinity to cpuset fc instead.
# WARNING: Failed to set thread affinity for cpuset 80. errno = 22. Setting the thread affinity to cpuset fc instead.
# WARNING: Failed to set thread affinity for cpuset 80. errno = 22. Setting the thread affinity to cpuset fc instead.
# WARNING: Failed to set thread affinity for cpuset 80. errno = 22. Setting the thread affinity to cpuset fc instead.
# Processing DNN input(s):
# ./raw/img1.raw
# Processing DNN input(s):
# ./raw/img2.raw
# Processing DNN input(s):
# ./raw/img3.raw
# Processing DNN input(s):
# ./raw/img4.raw
# Processing DNN input(s):
# ./raw/img5.raw
# Processing DNN input(s):
# ./raw/img6.raw
# Processing DNN input(s):
# ./raw/img7.raw
# Processing DNN input(s):
# ./raw/img8.raw
# Processing DNN input(s):
# ./raw/img9.raw
# Processing DNN input(s):
# ./raw/img10.raw
# Processing DNN input(s):
# ./raw/img11.raw
# Processing DNN input(s):
# ./raw/img12.raw
# Processing DNN input(s):
# ./raw/img13.raw
# Successfully executed!

# %% [markdown]
# # Pulling Output folder generated on different precision and cores

# %%
# %%bash
# rm -rf output/OUTPUT_8b_DSP
# rm -rf output/OUTPUT_32b_CPU

# %%
# %%bash
# export DEVICE_SHELL="adb -H $DEVICE_HOST -s $DEVICE_ID"
# $DEVICE_SHELL pull /data/local/tmp/$ONDEVICE_FOLDER/OUTPUT_8b_DSP output/OUTPUT_8b_DSP
# $DEVICE_SHELL pull /data/local/tmp/$ONDEVICE_FOLDER/OUTPUT_32b_CPU output/OUTPUT_32b_CPU
# Out:
# /data/local/tmp/sesr/OUTPUT_8b_DSP/: 16 files pulled. 87.3 MB/s (44257936 bytes in 0.483s)
# /data/local/tmp/sesr/OUTPUT_32b_CPU/: 16 files pulled. 66.3 MB/s (44219008 bytes in 0.636s)

# %% [markdown]
# # Calculate PSNR
# * Pass path of two raw image in Argument.

# %%
val = []
for i in range(10):
    val.append(IMAGES_HR[i])
val[0].shape
# Out:
# (512, 512, 3)

# %%
folder = ["output/OUTPUT_8b_DSP/","output/OUTPUT_32b_CPU"]
RGB_WEIGHTS = torch.FloatTensor([65.481, 128.553, 24.966])
for j in range(0,len(folder)):
    IMAGES_SR = []
    for i in range(0,10):
        IMAGES_SR.append(post_process_sr(folder[j]+"/Result_"+str(i)+"/94.raw"))
    print(folder[j]," (Average PSNR) :: ",evaluate_average_psnr(IMAGES_SR, IMAGES_HR))
    print("\n============================\n")

# %%
import matplotlib.pyplot as plt
plt.imshow(IMAGES_SR[5])

# %%
plt.imshow(IMAGES_HR[5])
